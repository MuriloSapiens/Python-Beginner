# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 4</font>
#
# ## Download: http://github.com/dsacademybr

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.8.8

# %% [markdown]
# ## Datetime
# Esse módulo permite a manipulação de datas em Python.

# %%
import datetime

# %%
agora = datetime.datetime.now()

# %%
agora # ele vai retornar o ano,mes,dia,hora,minuto,sugundo
# Out:
# datetime.datetime(2023, 1, 13, 19, 34, 31, 346776)

# %%
t = datetime.time(7, 43, 28)

# %%
print (t)
# Out:
# 07:43:28

# %%
print ('Hora  :', t.hour)
print ('Minute:', t.minute)
print ('Segundo:', t.second)
print ('Microsegundo:', t.microsecond)
# Out:
# Hora  : 7
# Minute: 43
# Segundo: 28
# Microsegundo: 0

# %%
print(datetime.time.min)
# Out:
# 00:00:00

# %%
hoje = datetime.date.today()

# %%
print (hoje)
print ('ctime:', hoje.ctime())
print ('Ano:', hoje.year)
print ('Mês :', hoje.month)
print ('Dia :', hoje.day)
# Out:
# 2023-01-13
# ctime: Fri Jan 13 00:00:00 2023
# Ano: 2023
# Mês : 1
# Dia : 13

# %%
d1 = datetime.date(2015, 4, 28)
print ('d1:', d1)
# Out:
# d1: 2015-04-28

# %%
d2 = d1.replace(year=2016)
print ('d2:', d2)
# Out:
# d2: 2016-04-28

# %%
# Diferença em dias entre duas datas
d2 - d1
# Out:
# datetime.timedelta(days=366)

# %% [markdown]
# # FIM

# %% [markdown]
# ### Obrigado
#
# ### Visite o Blog da Data Science Academy - <a href="http://blog.dsacademy.com.br">Blog DSA</a>
